# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mymoviedb.csv',lineterminator='\n')

df.head()
# Out:
#   Release_Date                    Title  \
# 0   15-12-2021  Spider-Man: No Way Home
# 1   01-03-2022               The Batman
# 2   25-02-2022                  No Exit
# 3   24-11-2021                  Encanto
# 4   22-12-2021           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#         9837 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Popularity
# count  9827.000000
# mean     40.320570
# std     108.874308
# min       7.100000
# 25%      16.127500
# 50%      21.191000
# 75%      35.174500
# max    5083.954000

# %% [markdown]
# Exploratory Summary
#  .We Have a Dataframe consisting of 9837 rows  and 9 columns.
#  .our data looks a bit tidy with no - NaN values or Duplicate values.
#  .Overview,original language and post_url not required,so we drop them.
#  .There is no noticable outliers in popularity column.

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'], errors='coerce', dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#         9837 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 691.8+ KB

# %%
df['Release_Year'] = df['Release_Date'].dt.year.astype('Int32')
df['Release_Year'].dtypes
# Out:
# Int32Dtype()

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#         9837 non-null   object
#  9   Release_Year       9827 non-null   Int32
# dtypes: Int32(1), datetime64[ns](1), float64(1), object(7)
# memory usage: 739.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   datetime64[ns]
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#         9837 non-null   object
#  9   Release_Year       9827 non-null   Int32
# dtypes: Int32(1), datetime64[ns](1), float64(1), object(7)
# memory usage: 739.8+ KB

# %%
cols = ['Overview','Original_Language','Poster_Url\r']
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.drop(cols,axis = 1,inplace = True,errors = 'ignore')
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Popularity', 'Vote_Count', 'Vote_Average',
#        'Genre', 'Release_Year'],
#       dtype='object')

# %%
df.head()
# Out:
#   Release_Date                    Title  Popularity Vote_Count Vote_Average  \
# 0   2021-12-15  Spider-Man: No Way Home    5083.954       8940          8.3
# 1   2022-03-01               The Batman    3827.658       1151          8.1
# 2   2022-02-25                  No Exit    2618.087        122          6.3
# 3   2021-11-24                  Encanto    2402.201       5076          7.7
# 4   2021-12-22           The King's Man    1895.511       1793            7
#
#                                 Genre  Release_Year
# 0  Action, Adventure, Science Fiction          2021
# 1            Crime, Mystery, Thriller          2022
# 2                            Thriller          2022
# 3  Animation, Comedy, Family, Fantasy          2021
# 4    Action, Adventure, Thriller, War          2021

# %% [markdown]
# Catigorize Vote_Average column
#
# We would cut the Vote_Average value and make 4 categories :Popular,Average,Below Average and Not Popular using catigorize_col() function

# %% [markdown]
# df.head(2000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  9827 non-null   datetime64[ns]
#  1   Title         9828 non-null   object
#  2   Popularity    9827 non-null   float64
#  3   Vote_Count    9827 non-null   object
#  4   Vote_Average  9827 non-null   object
#  5   Genre         9826 non-null   object
#  6   Release_Year  9827 non-null   Int32
# dtypes: Int32(1), datetime64[ns](1), float64(1), object(4)
# memory usage: 509.3+ KB

# %%
df['Vote_Average'] = pd.to_numeric(df['Vote_Average'], errors='coerce')
df['Vote_Average'].dtypes
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  9827 non-null   datetime64[ns]
#  1   Title         9828 non-null   object
#  2   Popularity    9827 non-null   float64
#  3   Vote_Count    9827 non-null   object
#  4   Vote_Average  9826 non-null   float64
#  5   Genre         9826 non-null   object
#  6   Release_Year  9827 non-null   Int32
# dtypes: Int32(1), datetime64[ns](1), float64(2), object(3)
# memory usage: 509.3+ KB

# %%
def catigorize_cols(df,col,labels):
    edges = [df[col].describe()['min'],
             df[col].describe()['25%'],
             df[col].describe()['50%'],
             df[col].describe()['75%'],
             df[col].describe()['max']]
    df[col] = pd.cut(df[col],edges,labels = labels,duplicates = 'drop')
    return df

# %%
labels = ['Not_Popular','Below_Average','Average','Popular']
catigorize_cols(df,'Vote_Average',labels)
df['Vote_Average'].unique()
# Out:
# ['Popular', 'Below_Average', 'Average', 'Not_Popular', NaN]
# Categories (4, object): ['Not_Popular' < 'Below_Average' < 'Average' < 'Popular']

# %%
df['Vote_Average'].value_counts()
# Out:
# Vote_Average
# Not_Popular      2467
# Popular          2450
# Average          2411
# Below_Average    2398
# Name: count, dtype: int64

# %%
df.dropna(inplace = True)

df.isna().sum()
# Out:
# Release_Date    0
# Title           0
# Popularity      0
# Vote_Count      0
# Vote_Average    0
# Genre           0
# Release_Year    0
# dtype: int64

# %% [markdown]
# We Would split the genre into a list and then explore our data frame to have only one genre per row

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9726 entries, 0 to 9836
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Release_Date  9726 non-null   datetime64[ns]
#  1   Title         9726 non-null   object
#  2   Popularity    9726 non-null   float64
#  3   Vote_Count    9726 non-null   object
#  4   Vote_Average  9726 non-null   category
#  5   Genre         9726 non-null   object
#  6   Release_Year  9726 non-null   Int32
# dtypes: Int32(1), category(1), datetime64[ns](1), float64(1), object(3)
# memory usage: 513.1+ KB

# %%
df['Genre'] = df['Genre'].str.split(', ')
df = df.explode('Genre').reset_index(drop = False)
df.head()
# Out:
#    index Release_Date                    Title  Popularity Vote_Count  \
# 0      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 1      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 2      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 3      1   2022-03-01               The Batman    3827.658       1151
# 4      1   2022-03-01               The Batman    3827.658       1151
#
#   Vote_Average            Genre  Release_Year
# 0      Popular           Action          2021
# 1      Popular        Adventure          2021
# 2      Popular  Science Fiction          2021
# 3      Popular            Crime          2022
# 4      Popular          Mystery          2022

# %%
df['Genre'] = df['Genre'].astype('category')
df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         25551 non-null  int64
#  1   Release_Date  25551 non-null  datetime64[ns]
#  2   Title         25551 non-null  object
#  3   Popularity    25551 non-null  float64
#  4   Vote_Count    25551 non-null  object
#  5   Vote_Average  25551 non-null  category
#  6   Genre         25551 non-null  category
#  7   Release_Year  25551 non-null  Int32
# dtypes: Int32(1), category(2), datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df.nunique()
# Out:
# index           9726
# Release_Date    5845
# Title           9414
# Popularity      8087
# Vote_Count      3265
# Vote_Average       4
# Genre             19
# Release_Year     100
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # Q-1 What is the Most frequent genre  of movies on netflix

# %%
df['Genre'].value_counts().plot(kind='barh', color='blue',width = 0.6) 
plt.xlabel('Count')
plt.ylabel('Genre')
plt.title('Genre column distribution')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
#  # Q-2 Which has the Highest Vote in Vote_Average column

# %%
df.head()
# Out:
#    index Release_Date                    Title  Popularity Vote_Count  \
# 0      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 1      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 2      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 3      1   2022-03-01               The Batman    3827.658       1151
# 4      1   2022-03-01               The Batman    3827.658       1151
#
#   Vote_Average            Genre  Release_Year
# 0      Popular           Action          2021
# 1      Popular        Adventure          2021
# 2      Popular  Science Fiction          2021
# 3      Popular            Crime          2022
# 4      Popular          Mystery          2022

# %%
sns.catplot(y = 'Vote_Average',data = df,kind = 'count',
            order = df['Vote_Average'].value_counts().index,
            color = '#4287f5')

plt.title('Vote Distribution')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25551 entries, 0 to 25550
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         25551 non-null  int64
#  1   Release_Date  25551 non-null  datetime64[ns]
#  2   Title         25551 non-null  object
#  3   Popularity    25551 non-null  float64
#  4   Vote_Count    25551 non-null  object
#  5   Vote_Average  25551 non-null  category
#  6   Genre         25551 non-null  category
#  7   Release_Year  25551 non-null  Int32
# dtypes: Int32(1), category(2), datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df[df['Popularity']==df['Popularity'].max()]
# Out:
#    index Release_Date                    Title  Popularity Vote_Count  \
# 0      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 1      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
# 2      0   2021-12-15  Spider-Man: No Way Home    5083.954       8940
#
#   Vote_Average            Genre  Release_Year
# 0      Popular           Action          2021
# 1      Popular        Adventure          2021
# 2      Popular  Science Fiction          2021

# %% [markdown]
# # Which Movie has lowest popularity?What is genre

# %%
df[df['Popularity']==df['Popularity'].min()]
# Out:
#        index Release_Date                                 Title  Popularity  \
# 25545   9835   2021-03-31  The United States vs. Billie Holiday      13.354
# 25546   9835   2021-03-31  The United States vs. Billie Holiday      13.354
# 25547   9835   2021-03-31  The United States vs. Billie Holiday      13.354
# 25548   9836   1984-09-23                               Threads      13.354
# 25549   9836   1984-09-23                               Threads      13.354
# 25550   9836   1984-09-23                               Threads      13.354
#
#       Vote_Count Vote_Average            Genre  Release_Year
# 25545        152      Average            Music          2021
# 25546        152      Average            Drama          2021
# 25547        152      Average          History          2021
# 25548        186      Popular              War          1984
# 25549        186      Popular            Drama          1984
# 25550        186      Popular  Science Fiction          1984

# %% [markdown]
#  # Which Year has Most Filmmed Movies?

# %%
df['Release_Date'].hist()
plt.title('Release_Date column distribution')
plt.show()

# %% [markdown]
# Conclusion:
# Q-1:What is the Most frequent genre of movies on netflix
# Drama genre is most frequent genre of our dataset and has appeared more than 14% of the time among 19
# Q-2:Which has the Highest Vote in Vote_Average column
# Drama against get highest vote in our dataset and have 25.5% of our dataset
# Q-3:Which Movie has Highest popularity?What is genre
# Spiderman-No way home has  Highest popularity and its genre is Action,Adventure and Science Fiction
# Q-4:Which Movie has Lowest popularity?What is genre
# The United States vs. Billie Holiday has lowest popularity and its genre is Music,Drama and  History
